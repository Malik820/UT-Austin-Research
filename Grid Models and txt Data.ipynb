# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
import os
from astropy.io import fits
import scipy.interpolate
from scipy.interpolate import splev, splrep
from scipy import interpolate
import scipy.interpolate as spi

# %%
def new_degrade_R(input_wl, input_fl, wl_range, Res):
    ''' using established routine from the python module “coronagraph”
    '''
    import coronagraph as cg
    lowres_wl, lowres_dwl = cg.noise_routines.construct_lam(wl_range[0], wl_range[1], Res=Res)
    lowres_fl = cg.downbin_spec(input_fl, input_wl, lowres_wl, dlam=lowres_dwl)
    return lowres_wl, lowres_fl

# %%
filenames1 = []
for f_name1 in os.listdir('/Users/bosse/Pictures/Observed Spectra txt files/'):
    if f_name1.endswith('.txt'):
            filenames1.append(f_name1)
print(filenames1)
filename1 = filenames1[:]
direc = '/Users/bosse/Pictures/Observed Spectra txt files/'
for i in range(len(filename1)):
    #with fits.open(direc+ str(filename1[i])) as hdul1:
    data = np.loadtxt(direc+ str(filename1[i]))
    w = data[:,0]
    f = data[:,1]
    plt.plot(w,f)
    plt.xlim(0.8, 2.5)
    plt.show();
# Out:
# ['004.71462+51.89168_PSOJ004.7148+51.8918_J00185151+5153306_20130922_R=150_Q=OK.txt', '004.91362-37.41089_2MASSJ00193927-3724392_J00193927-3724392_20030904_R=75_Q=OK.txt', '006.92487+05.06158_PC0025+04_J00274197+0503417_20120920_R=120_Q=OK.txt', '007.79183+57.82675_WISEJ003110.04+574936.3_J00311004+5749363_20120924_R=75_Q=OK.txt', '008.23267-44.08494_EROS-MPJ0032-4405_J00325584-4405058_20080815_R=120_Q=OK.txt', '008.34942-15.35858_2MASSJ00332386-1521309_J00332386-1521309_20081129_R=120_Q=OK.txt', '010.47721+13.69308_SDSSJ004154.54+134135.5_J00415453+1341351_20090124_R=120_Q=OK.txt', '011.70171+07.25492_2MASSJ00464841+0715177_J00464841+0715177_20080713_R=120_Q=OK.txt', '011.75442+68.06448_WISEPJ004701.06+680352.1_J00470106+6803521_20110721_R=120_Q=OK.txt', '014.67721-06.85664_2MASSWJ0058425-065123_J00584253-0651239_20080714_R=120_Q=OK.txt', '021.58788+14.46822_2MASSJ01262109+1428057_J01262109+14280569_20061208_R=120_Q=OK.txt', '026.88933+34.88645_2MASSWJ0147334+345311_J01473344+3453112_20080908_R=120_Q=OK.txt', '040.29796-03.44964_2MASSJ02411151-0326587_J02411151-0326587_20081201_R=120_Q=OK.txt', '049.18796-28.81444_2MASSIJ0316451-284852_J03164511-28485209_20131205_R=120_Q=OK.txt', '050.79183-46.52397_2MASSJ03231004-4631263_J03231004-4631263_20071112_R=120_Q=OK.txt', '051.67604-21.03492_2MASSJ03264225-2102057_J03264225-2102057_20071112_R=120_Q=OK.txt', '053.75866+23.70989_2MASSJ03350208+2342356_J03350208+2342356_20081130_R=120_Q=OK.txt', '057.28933+15.24333_PSOJ057.2893+15.2433_J03490944+1514360_20140118_R=150_Q=OK.txt', '058.84738+11.56214_2MASSJ03552337+1133437_J03552337+1133437_20091207_R=120_Q=OK.txt', '059.36229-44.29181_DENIS-PJ035729.6-441730_J03572695-4417305_20070916_R=120_Q=OK.txt', '068.92875+13.39583_2MASSJ04354290+1323449_J043542903+1323449_20121107_R=150_Q=OK.txt', '070.90671+00.03475_SDSSJ044337.61+000205.1_J04433761+0002051_20131205_R=120_Q=OK.txt', '071.87666-12.27112_PSOJ071.8769-12.2713_J04473040-1216164_20130126_R=150_Q=OK.txt', '073.36029-17.86508_2MASSIJ0453264-175154_J04532647-1751543_20091104_R=120_Q=OK.txt', '078.02650-29.83167_2MASSJ05120636-2949540_J05120636-29495400_20131029_R=120_Q=OK.txt', '078.99033+31.01697_PSOJ078.9904+31.0171_J05155768+3101018_20150128_R=150_Q=OK.txt', '079.69234-27.94603_2MASSJ05184616-2756457_J05184616-2756457_20080924_R=120_Q=OK.txt', '082.24038+09.01789_WISEJ052857.68+090104.4_J05285768+0901044_20120131_R=120_Q=OK.txt', '084.08324-19.34433_2MASSJ05361998-1920396_J05361998-1920396_20120920_R=120_Q=OK.txt', '085.82863+64.38133_2MASSJ05431887+6422528_J05431887+6422528_20080109_R=120_Q=OK.txt', '089.46233-13.99731_2MASSJ05575096-1359503_J05575096-1359503_20080127_R=200_Q=OK.txt', '090.62687+39.18311_LSR0602+3910_J06023045+3910592_20091104_R=120_Q=OK.txt', '092.22012-27.89953_2MASSJ06085283-2753583_J06085283-2753583_20060902_R=120_Q=OK.txt', '096.83363-11.24111_WISEJ062720.07-111428.0_J06272007-1114280_20101218_R=120_Q=OK.txt', '119.50671-25.65039_HIP38939B_J07580161-2539014_20110331_R=120_Q=OK.txt', '122.49596+44.57267_SDSSJ080959.01+443422.2_J08095903+4434216_20080112_R=120_Q=OK.txt', '124.99187-03.59125_WISEJ081958.05-033528.5_J08195805-0335285_20101218_R=120_Q=OK.txt', '132.64970+10.95433_2MASSsJ0850359+105716_J08503593+1057156_20050324_R=120_Q=OK.txt', '134.65404+27.18078_SDSSJ08583697+2710508_J08583697+2710508_20110309_R=120_Q=OK.txt', '148.33858-10.23903_2MASSJ09532126-1014205_J09532126-1014205_20061220_R=120_Q=OK.txt', '149.19063-19.17279_PSOJ149.1907-19.1730_J09564575-1910223_20131123_R=150_Q=OK.txt', '151.08609+50.38322_G196-3B_J10042066+5022596_20061223_R=120_Q=OK.txt', '151.16371-33.58855_LHS5166B_J10043929-33351889_20130426_R=120_Q=OK.txt', '155.52037+02.01325_2MASSJ10220489+0200477_J10220489+0200477_20080110_R=120_Q=OK.txt', '155.70087+58.42925_2MASSJ10224821+5825453_J10224821+5825453_20080111_R=120_Q=OK.txt', '159.04324-27.63556_PSOJ159.0433-27.6357_J10361038-2738083_20130417_R=150_Q=OK.txt', '170.72800+25.83950_WISEJ112254.72+255022.2_J11225472+2550222_20100714_R ...

# %%
filenames1 = []
for f_name1 in os.listdir('/Users/bosse/Pictures/Primary Grid Models/'):
     filenames1.append(f_name1)
print(filenames1)
filename1 = filenames1[:]
direc = '/Users/bosse/Pictures/Primary Grid Models/'
for i in range(len(filename1)):
    #with fits.open(direc+ str(filename1[i])) as hdul1:
    data4 = np.loadtxt(direc+ str(filename1[i]), skiprows = 2)
    w4 = data4[:,0]
    f4 = data4[:,1]
    plt.plot(w4,f4)
    plt.xlim(0.8, 2.5)
    plt.show();

# %%
filenames1 = []
for f_name1 in os.listdir('/Users/bosse/Pictures/Observed Spectra fits files/'):
    if f_name1.endswith('.fits'):
            filenames1.append(f_name1)
print(filenames1)
filename1 = filenames1[:]
direc = '/Users/bosse/Pictures/Observed Spectra fits files/'
for i in range(len(filename1)):
    with fits.open(direc + str(filename1[i])) as hdul1:
    #data = np.loadtxt(direc+ str(filename1[i]))
        data2 = hdul1[0].data
        w2 = data2[0]
        f2 = data2[1]
        plt.plot(w2,f2)
        plt.show();
print()

# %%
teff_grid = np.array([800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200, 2300, 2400])
num_teff = len(teff_grid)
logg_grid = np.array([4,4.5,5,5.5])
num_logg = len([logg_grid])
logg_dict = {4:"100",
            4.5:"300",
            5:"1000",
            5.5:"3000"}
f_sed_dict = {1:"f1",
             2:"f2",
             3:"f3",
             4:"f4",
             10:"nc"}
f_sed_grid = np.array([1,2,3,4,10])
num_f_sed = len([f_sed_grid])
num_model = num_teff * num_logg * num_f_sed
grid_param = []
for teff in teff_grid:
    for logg in logg_grid:
        for f in f_sed_grid:
            grid_param.append([teff, logg, f])
grid_param = np.array(grid_param)
print(grid_param)
N = len(grid_param)
print(N)
# Out:
# [[8.0e+02 4.0e+00 1.0e+00]
#  [8.0e+02 4.0e+00 2.0e+00]
#  [8.0e+02 4.0e+00 3.0e+00]
#  ...
#  [2.4e+03 5.5e+00 3.0e+00]
#  [2.4e+03 5.5e+00 4.0e+00]
#  [2.4e+03 5.5e+00 1.0e+01]]
# 340

# %% [raw]
# data_folder = '/Users/bosse/Pictures/Observed Spectra fits files/'
#
# hdul1 = fits.open(data_folder + 'CC_CCv2.0_32207_32010_0.8prism_2018nov022020feb16mar10.fits')[0].data
# w_data = hdul1[0]
# f_data = hdul1[1]
# u_data = hdul1[2]
# id_good = np.where((np.isnan(f_data) == False) & (u_data != 0))
# w_data = w_data[id_good]
# f_data = f_data[id_good]
# u_data = u_data[id_good]
# num_pixels = len(w_data)

# %%
#Load obsevred spectra file 
data_folder = '/Users/bosse/Pictures/Observed Spectra fits files/'

hdul1 = fits.open(data_folder + 'Ross458C_0.5prism_2015jul07.fits')[0].data
w_data = hdul1[0]
f_data = hdul1[1]
u_data = hdul1[2]
id_good = np.where((np.isnan(f_data) == False) & (u_data != 0) & (w_data > 0.8) & (w_data < 2.5))
w_data = w_data[id_good]
f_data = f_data[id_good]
u_data = u_data[id_good]
num_pixels = len(w_data)
# Defined image arrays 
C_k_array = np.ones(N) * np.nan
G_k_array = np.ones(N) * np.nan
#Load model data into a for loop
#for index in range(len(grid_param)):
for index in range(N):
    teff, logg, f = grid_param[index]
    Model_folder = '/Users/bosse/Pictures/Primary Grid Models/'
# Load Model
    try:
        model_array = np.genfromtxt(Model_folder + "sp_t%dg%s%s"%(teff, logg_dict[logg], f_sed_dict[f]), skip_header = 2)
        w_model = model_array[:,0]
        f_model = model_array[:,1]
    except OSError or FileNotFoundError:
#Downgrade Resolution then Model Interpolation
        print("sp_t%dg%s%s not there"%(teff, logg_dict[logg], f_sed_dict[f]))
        continue
    (new_w_model, new_f_model) = new_degrade_R(input_wl = w_model, input_fl = f_model, wl_range = [0.8,2.5], Res = 100)
    intfunc = spi.interp1d(new_w_model, new_f_model, fill_value="extrapolate")
    f_model_interp = intfunc(w_data)
#Compute C_k
    C_knum = 0
    for i in range(num_pixels):
        v = f_data[i] * f_model_interp[i] / u_data[i]**2
        C_knum = C_knum + v
    C_kden = 0
    for i in range(num_pixels):
        v2 = (f_model_interp[i]**2)/(u_data[i]**2)
        C_kden = C_kden + v2
    C_k = C_knum/C_kden
    G_k = 0 
    for i in range(num_pixels):
        v3 = ((f_data[i] - C_k * f_model_interp[i]) / u_data[i])**2
        G_k = G_k + v3
    C_k_array[index] = C_k
    G_k_array[index] = G_k
print(C_k_array, G_k_array)
# Out:
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
#  ############################## Xspextool History ############################## [astropy.io.fits.card]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
#  ############################## Xcombspec History ############################## [astropy.io.fits.card]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
#  ############################### Xtellcor History ############################## [astropy.io.fits.card]
# sp_t800g100f1 not there
# sp_t800g100f3 not there
# sp_t800g100f4 not there
# sp_t900g100f3 not there
# sp_t900g100f4 not there
# sp_t900g1000f1 not there
# sp_t1000g100f1 not there
# sp_t1000g100f3 not there
# sp_t1000g100f4 not there
# sp_t1000g300f1 not there
# sp_t1200g1000f1 not there
# sp_t1200g1000f2 not there
# sp_t1300g300f1 not there
# sp_t1400g100f1 not there
# sp_t1400g1000f1 not there
# sp_t1500g100f1 not there
# sp_t1500g100f2 not there
# sp_t1500g100f3 not there
# sp_t1500g100f4 not there
# sp_t1500g300f2 not there
# sp_t1600g100f1 not there
# sp_t1600g100f2 not there
# sp_t1600g100f4 not there
# sp_t1600g300f1 not there
# sp_t1600g3000f1 not there
# sp_t1600g3000f2 not there
# sp_t1600g3000f3 not there
# sp_t1700g100f1 not there
# sp_t1700g100f2 not there
# sp_t1700g100f4 not there
# sp_t1700g1000f1 not there
# sp_t1800g100f1 not there
# sp_t1800g100f3 not there
# sp_t1800g3000f2 not there
# sp_t1900g100f1 not there
# sp_t1900g100f3 not there
# sp_t1900g100f4 not there
# sp_t2000g100f1 not there
# sp_t2000g100f3 not there
# sp_t2000g100f4 not there
# sp_t2100g100f1 not there
# sp_t2100g100f3 not there
# sp_t2100g100f4 not there
# sp_t2200g100f1 not there
# sp_t2200g100f3 not there
# sp_t2200g100f4 not there
# sp_t2300g100f1 not there
# sp_t2300g100f3 not there
# sp_t2300g100f4 not there
# sp_t2400g100f1 not there
# sp_t2400g100f3 not there
# sp_t2400g100f4 not there
# [           nan 3.56759965e-09            nan            nan
#  3.82177061e-09 3.23180458e-09 3.67873250e-09 3.96422304e-09
#  3.81401423e-09 3.89217313e-09 3.13685575e-09 4.04889214e-09
#  3.93008711e-09 3.74811446e-09 3.83329479e-09 2.58030729e-09
#  4.23977262e-09 3.77018432e-09 3.73775477e-09 3.82470798e-09
#  1.39166781e-09 1.88956548e-09            nan            nan
#  2.28121234e-09 1.45030018e-09 1.86730527e-09 2.20939391e-09
#  2.21994181e-09 2.29434872e-09            nan 2.07383758e-09
#  2.20292873e-09 2.18262023e-09 2.23963270e-09 1.25496422e-09
#  2.05780760e-09 2.22884557e-09 2.17225035e-09 2.20288152e-09
#             nan 1.12027110e-09            nan            nan
#  1.43034523e-09            nan 1.04793907e-09 1.29434418e-09
#  1.36576369e-09 1.43670673e-09 7.87517948e-10 1.06271129e-09
#  1.28363591e-09 1.34864440e-09 1.38972291e-09 6.92519839e-10
#  133007.09441753 132905.74782939 132802.46523167 130589.46493652]

# %%
#C_knum = np.sum(f_data * f_model_interp / u_data**2)

# %%
direc = '/Users/bosse/Pictures/Observed Spectra txt files/'
for i in range(len(filename1)):
    #with fits.open(direc+ str(filename1[i])) as hdul1:
    data = np.loadtxt(direc+ str(filename1[i]))
    w_data = data[:,0]
    f_data = data[:,1]
    u_data = data[:,2]
    id_good = np.where((np.isnan(f_data) == False) & (u_data != 0) & (w_data > 0.8) & (w_data < 2.5))
    w_data = w_data[id_good]
    f_data = f_data[id_good]
    u_data = u_data[id_good]
    num_pixels = len(w_data)
# Defined image arrays 
    C_k_array = np.ones(N) * np.nan
    G_k_array = np.ones(N) * np.nan
#Load model data into a for loop
#for index in range(len(grid_param)):
    for index in range(N):
        teff, logg, f = grid_param[index]
        Model_folder = '/Users/bosse/Pictures/Primary Grid Models/'
# Load Model
        try:
            model_array = np.genfromtxt(Model_folder + "sp_t%dg%s%s"%(teff, logg_dict[logg], f_sed_dict[f]), skip_header = 2)
            w_model = model_array[:,0]
            f_model = model_array[:,1]
        #except OSError or FileNotFoundError:
#Downgrade Resolution then Model Interpolation
            #print("sp_t%dg%s%s not there"%(teff, logg_dict[logg], f_sed_dict[f]))
            #continue
            (new_w_model, new_f_model) = new_degrade_R(input_wl = w_model, input_fl = f_model, wl_range = [0.8,2.5], Res = 100)
            intfunc = spi.interp1d(new_w_model, new_f_model, fill_value="extrapolate")
            f_model_interp = intfunc(w_data)
            C_knum = 0
            for i in range(num_pixels):
                v = f_data[i] * f_model_interp[i] / u_data[i]**2
                C_knum = C_knum + v
            C_kden = 0
            for i in range(num_pixels):
                v2 = (f_model_interp[i]**2)/(u_data[i]**2)
                C_kden = C_kden + v2
            C_k = C_knum/C_kden
            G_k = 0 
            for i in range(num_pixels):
                v3 = ((f_data[i] - C_k * f_model_interp[i]) / u_data[i])**2
                G_k = G_k + v3
            C_k_array[index] = C_k
            G_k_array[index] = G_k
        except OSError or FileNotFoundError:
#Downgrade Resolution then Model Interpolation
            print("sp_t%dg%s%s not there"%(teff, logg_dict[logg], f_sed_dict[f]))
            continue
    #print(C_k_array, G_k_array)
    teff_best, logg_best, f_sed_best = grid_param[np.nanargmin(G_k_array)]
    model_array_best = np.genfromtxt(Model_folder + "sp_t%dg%s%s"%(teff_best, logg_dict[logg_best], f_sed_dict[f_sed_best]), skip_header = 2)
    w_model_best = model_array_best[:,0]
    f_model_best = model_array_best[:,1]
    (new_w_model_best, new_f_model_best) = new_degrade_R(input_wl = w_model_best, input_fl = f_model_best, wl_range = [0.8,2.5], Res = 100)
    intfunc = spi.interp1d(new_w_model_best, new_f_model_best, fill_value="extrapolate")
    C_k_lowest = C_k_array[np.nanargmin(G_k_array)]
    f_model_interp = intfunc(w_data)*C_k_lowest
    plt.plot(w_data, f_model_interp, label = 'Interpolated Model')  
    plt.plot(w_data, f_data, label = 'Observed Spectra')
#plt.fill_between(w_data, f_data - u_data, f_data + u_data, color='red', alpha=0.3)
    plt.title("Interpolation of Model values over Observed Spectra")
    plt.title("Teff = %d , logg = %.1f , fsed = %s"%(teff_best, logg_best, f_sed_dict[f_sed_best]))
    plt.xlabel("Wavelength(Microns)")
    plt.ylabel("Flux")
    plt.legend()
    plt.show()
# Out:
# sp_t800g100f1 not there
# sp_t800g100f3 not there
# sp_t800g100f4 not there
# sp_t900g100f3 not there
# sp_t900g100f4 not there
# sp_t900g1000f1 not there
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#      21 # Load Model
#      22         try:
# ---> 23             model_array = np.genfromtxt(Model_folder + "sp_t%dg%s%s"%(teff, logg_dict[logg], f_sed_dict[f]), skip_header = 2)
#      24             w_model = model_array[:,0]
#      25             f_model = model_array[:,1]
#
# File ~\anaconda3\lib\site-packages\numpy\lib\npyio.py:2059, in genfromtxt(fname, dtype, comments, delimiter, skip_header, skip_footer, converters, missing_values, filling_values, usecols, names, excludelist, deletechars, replace_space, autostrip, case_sensitive, defaultfmt, unpack, usemask, loose, invalid_raise, max_rows, encoding, like)
#    2056 append_to_invalid = invalid.append
#    2058 # Parse each line
# -> 2059 for (i, line) in enumerate(itertools.chain([first_line, ], fhd)):
#    2060     values = split_line(line)
#    2061     nbvalues = len(values)
#
# File ~\anaconda3\lib\encodings\cp1252.py:22, in IncrementalDecoder.decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
# ---> 22     def decode(self, input, final=False):
#      23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#
# KeyboardInterrupt:

# %%
filename2 = []
directory = '/Users/bosse/Pictures/Observed Spectra fits files/'
for i in range(len(filename2)):
    hdul1 = fits.open(directory+ str(filename2[i]))
    w_data = hdul1[0]
    f_data = hdul1[1]
    u_data = hdul1[2]
    id_good = np.where((np.isnan(f_data) == False) & (u_data != 0) & (w_data > 0.8) & (w_data < 2.5))
    w_data = w_data[id_good]
    f_data = f_data[id_good]
    u_data = u_data[id_good]
    num_pixels = len(w_data)
# Defined image arrays 
    C_k_array = np.ones(N) * np.nan
    G_k_array = np.ones(N) * np.nan
#Load model data into a for loop
#for index in range(len(grid_param)):
    for index in range(N):
        teff, logg, f = grid_param[index]
        Model_folder2 = '/Users/bosse/Pictures/Primary Grid Models/'
# Load Model
        try:
            model_array = np.genfromtxt(Model_folder2 + "sp_t%dg%s%s"%(teff, logg_dict[logg], f_sed_dict[f]), skip_header = 2)
            w_model = model_array[:,0]
            f_model = model_array[:,1]
            (new_w_model, new_f_model) = new_degrade_R(input_wl = w_model, input_fl = f_model, wl_range = [0.8,2.5], Res = 100)
            intfunc = spi.interp1d(new_w_model, new_f_model, fill_value="extrapolate")
            f_model_interp = intfunc(w_data)
            C_knum = 0
            for i in range(num_pixels):
                v = f_data[i] * f_model_interp[i] / u_data[i]**2
                C_knum = C_knum + v
            C_kden = 0
            for i in range(num_pixels):
                v2 = (f_model_interp[i]**2)/(u_data[i]**2)
                C_kden = C_kden + v2
            C_k = C_knum/C_kden
            G_k = 0 
            for i in range(num_pixels):
                v3 = ((f_data[i] - C_k * f_model_interp[i]) / u_data[i])**2
                G_k = G_k + v3
            C_k_array[index] = C_k
            G_k_array[index] = G_k
        except OSError or FileNotFoundError:
#Downgrade Resolution then Model Interpolation
            print("sp_t%dg%s%s not there"%(teff, logg_dict[logg], f_sed_dict[f]))
            continue
    #print(C_k_array, G_k_array)
    teff_best, logg_best, f_sed_best = grid_param[np.nanargmin(G_k_array)]
    model_array_best = np.genfromtxt(Model_folder + "sp_t%dg%s%s"%(teff_best, logg_dict[logg_best], f_sed_dict[f_sed_best]), skip_header = 2)
    w_model_best = model_array_best[:,0]
    f_model_best = model_array_best[:,1]
    (new_w_model_best, new_f_model_best) = new_degrade_R(input_wl = w_model_best, input_fl = f_model_best, wl_range = [0.8,2.5], Res = 100)
    intfunc = spi.interp1d(new_w_model_best, new_f_model_best, fill_value="extrapolate")
    C_k_lowest = C_k_array[np.nanargmin(G_k_array)]
    f_model_interp = intfunc(w_data)*C_k_lowest
    plt.plot(w_data, f_model_interp, label = 'Interpolated Model')  
    plt.plot(w_data, f_data, label = 'Observed Spectra')
#plt.fill_between(w_data, f_data - u_data, f_data + u_data, color='red', alpha=0.3)
    plt.title("Interpolation of Model values over Observed Spectra")
    plt.title("Teff = %d , logg = %.1f , fsed = %s"%(teff_best, logg_best, f_sed_dict[f_sed_best]))
    plt.xlabel("Wavelength(Microns)")
    plt.ylabel("Flux")
    plt.legend()
    plt.show()

# %%
plt.plot(w_data, f_model_interp, label = 'Interpolated Model')  
plt.plot(w_data, f_data, label = 'Observed Spectra')
#plt.fill_between(w_data, f_data - u_data, f_data + u_data, color='red', alpha=0.3)
plt.title("Interpolation of Model values over Observed Spectra")
plt.title("Teff = %d , logg = %.1f , fsed = %s"%(teff_best, logg_best, f_sed_dict[f_sed_best]))
plt.xlabel("Wavelength(Microns)")
plt.ylabel("Flux")
plt.legend()
plt.show()

# %%
print(np.nanargmin(G_k_array))
print(np.nanmin(G_k_array))

# %%
teff_best, logg_best, f_sed_best = grid_param[np.nanargmin(G_k_array)]

# %%
C_k_lowest = C_k_array[np.nanargmin(G_k_array)]
print(C_k_lowest)

# %%
model_array_best = np.genfromtxt(Model_folder + "sp_t%dg%s%s"%(teff_best, logg_dict[logg_best], f_sed_dict[f_sed_best]), skip_header = 2)
w_model_best = model_array_best[:,0]
f_model_best = model_array_best[:,1]
(new_w_model_best, new_f_model_best) = new_degrade_R(input_wl = w_model_best, input_fl = f_model_best, wl_range = [0.8,2.5], Res = 100)
intfunc = spi.interp1d(new_w_model_best, new_f_model_best, fill_value="extrapolate")
f_model_interp = intfunc(w_data)*C_k_lowest

# %%
id_select = np.where((grid_param[:,1] == 4) & (grid_param[:,2] == 10))
print(id_select)

# %%
plt.plot(grid_param[id_select,0].T, G_k_array[id_select], )
plt.show()

# %%
intfunc2 = spi.interp1d(w4, f4, fill_value="extrapolate")
flux3 = intfunc2(w)

# %%
plt.plot(w4, f4, label = "Model Values") 
plt.plot(w, flux3, label = 'Observed Spectra')       
plt.title("Interpolation of Model values over Observed Spectras")
plt.legend()
plt.show()

# %%
def comp_to_models(model_array)
for data in hdul1:
    comp_to_models(hdul1)

# %%
plt.plot(w_model, f_model, label = "Model Values") 
plt.plot(w_data, f_model_interp, label = 'Interpolated Model')  
plt.plot(w_data, f_data, label = 'Observed Spectra')       
plt.title("Interpolation of Model values over Observed Spectras")
plt.xlim(0.8,2.5)
plt.legend()
plt.show()

# %%
from astropy.visualization import astropy_mpl_style
plt.style.use(astropy_mpl_style)

# %%
from astropy.utils.data import get_pkg_data_filename
from astropy.io import fits
SDSS = get_pkg_data_filename('pm+HIP-912-80902_0.8prism_2012oct07.fits')

# %%
fits.info(SDSS)

# %%
SDSS_data = fits.getdata(SDSS, ext=0)

# %%
plt.plot(SDSS_data[0], SDSS_data[1])

# %%
w = SDSS_data[0]
f = SDSS_data[1]

# %%
def new_degrade_R(input_wl, input_fl, wl_range, Res):
    ''' using established routine from the python module “coronagraph”
    '''
    import coronagraph as cg
    lowres_wl, lowres_dwl = cg.noise_routines.construct_lam(wl_range[0], wl_range[1], Res=Res)
    lowres_fl = cg.downbin_spec(input_fl, input_wl, lowres_wl, dlam=lowres_dwl)
    return lowres_wl, lowres_fl

# %%
(new_w, new_f) = new_degrade_R(input_wl = w, input_fl = f, wl_range = [0.8,2.5], Res = 100)

# %%
plt.plot(new_w, new_f)
